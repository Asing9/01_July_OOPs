# %%
1. What is the primary goal of Object-Oriented Programming (OOP)?
ans: Reusable of program
    oops can solve real world problem

# %%
2. What is an object in Python?
python is object oriented programing language , object store memory allocation

# %%
3. What is a class in Python?

class is blueprint or prototype for creating objects.
every object belong to some class
class is combination of multiple methods, and attributes
class is user defined datatype

# %%
4. What are attributes and methods in a class ?

    attributes are we can say variables in class

    methods are functions defined inside the class

# %%
5. What is the difference between class variables and instance variables in Python?

# %%
class variables : are associated with class it will be same for all class, it will not change

instance variables : are associated with each object it will be different , it will chanage any time for any object

# %%
6. What is the purpose of the self parameter in Python class methods?

# %%
self is a variable which contain memory allocation of object

# %%
7. For a library management system, you have to design the "Book" class with OOP
principles in mind. The “Book” class will have following attributes:
a. title: Represents the title of the book.
b. author: Represents the author(s) of the book.
c. isbn: Represents the ISBN (International Standard Book Number) of the book.
d. publication_year: Represents the year of publication of the book.
e. available_copies: Represents the number of copies available for checkout.
The class will also include the following methods:
a. check_out(self): Decrements the available copies by one if there are copies
available for checkout.
b. return_book(self): Increments the available copies by one when a book is
returned.
c. display_book_info(self): Displays the information about the book, including its
attributes and the number of available copies.

# %%
class Book:
    def __init__(self,title,author,ISBN,PY,AC):
        self.Title_of_book=title
        self.Author_of_book=author
        self.ISBN=ISBN
        self.Publication_of_year=PY
        self.Avaliable_of_copies=AC


    def display(self):
        print(f"Title of Book: {self.Title_of_book}")
        print(f"Author of Book: {self.Author_of_book}")
        print(f"International standard book number: {self.ISBN}")
        print(f"Publication of year:{self.Publication_of_year}")
        print(f"Avaliable of copies: {self.Avaliable_of_copies}")

    def check_out(self,order):
        self.order=order
        print(f"Avaliable copies:{self.Avaliable_of_copies}")
        if self.Avaliable_of_copies>=0:

            c=self.Avaliable_of_copies-order
            print("after checkout ",c)

        else:
            print("not avaliable")
        now = self.Avaliable_of_copies = c
        print(now)


    def return_book(self,ret_book):

        self.ret_book=ret_book
        d=self.Avaliable_of_copies+ret_book
        print('After return book',d)
        now1=self.Avaliable_of_copies=d

    def display_book_info(self):
        if self.Title_of_book=="The Freedom Manifesto":
            print(f"What is your purpose, your Dharma, your innate tendency? Your only path to freedom is to be true to this.")
        if self.Title_of_book=="Iron Flame":
            print("Hunger Games meets Divergent in the epic next installment of the number one bestselling Empyrean series.")
        if self.Title_of_book=="Think And Grow Rich":
            print("Think and Grow Rich has earned itself The reputation of being considered a textbook for actionable techniques that can help one get better at doing anything, not just by rich and wealthy, but also by people doing wonderful work in their respective fields.")





b1=Book("The Freedom Manifesto","KARAN BAJAJ","B0BFJP92NL",'2022',50)
b2=Book("Iron Flame","Rebecca Yarros","0349437025",2023,20)
b3=Book("Think And Grow Rich","Napoleon Hill","9353338158",2020,64)

print(b1.display())
print(b2.display())
print(getattr(b1,"ISBN"))

b1.check_out(2)
print(b1.display())
b1.return_book(1)
print(b1.display())
b1.display_book_info()
b2.display_book_info()
b3.display_book_info()

# %%
8. For a ticket booking system, you have to design the "Ticket" class with OOP
principles in mind. The “Ticket” class should have the following attributes:
a. ticket_id: Represents the unique identifier for the ticket.
b. event_name: Represents the name of the event.
c. event_date: Represents the date of the event.
d. venue: Represents the venue of the event.
e. seat_number: Represents the seat number associated with the ticket.
f. price: Represents the price of the ticket.
g. is_reserved: Represents the reservation status of the ticket.
The class also includes the following methods:
a. reserve_ticket(self): Marks the ticket as reserved if it is not already reserved.
b. cancel_reservation(self): Cancels the reservation of the ticket if it is already
reserved.
c. display_ticket_info(self): Displays the information about the ticket, including its
attributes and reservation status.

# %%
class Ticket:
    event_name="Carnival of Colors"
    event_date="1-January"
    venue="ABC Stadium"
    total_Seat=20

    def __init__(self,tid,sno,pr,reserved):
        self.ticket_id=tid
        self.seat_no=sno
        self.price=pr
        self.reserved=reserved



    def reserve_ticket(self):

        
        if self.reserved=="Reserved":

            print("Seat Reserved")
        if Ticket.total_Seat >= 0:
            a = Ticket.total_Seat - self.reserved.count('reserved')
            print('seats',a)
            
            Ticket.total_Seat = a



            #print("avaliable seat", a)



    def cancle_reservation(self):
        if self.reserved==True:
            print("Cancle Avaliable")

    def display_ticket_info(self):
        print(f"Ticket ID:{self.ticket_id}")
        print(f"Seat Number:{self.seat_no}")
        print(f"Resvertation Status:{self.reserved}")
        print(f"Price :{self.price}")
        print(f"Event Name:{Ticket.event_name}")
        print(f"Event date:{Ticket.event_date}")
        print(f"Venue:{Ticket.venue}")
        print(f"Total Avaliable seat:{Ticket.total_Seat}")

print(Ticket.venue)
print(Ticket.event_date)
t1=Ticket(1,'A',50,"reserved")
print(t1.display_ticket_info())
print('============')
t2=Ticket(2,'B',50,"reserved")
print(t2.display_ticket_info())
print('*************')
t3=Ticket(3,'C',50,"reserved")
print(t3.display_ticket_info())
print('----------------')
t4=Ticket(4,"D",50,"Not reserved")
print(t4.display_ticket_info())
print("--------------")
t5=Ticket(5,"E",50,"reserved")
print(t5.reserve_ticket())
print("---------")
# Out:
# ABC Stadium
# 1-January
# Ticket ID:1
# Seat Number:A
# Resvertation Status:reserved
# Price :50
# Event Name:Carnival of Colors
# Event date:1-January
# Venue:ABC Stadium
# Total Avaliable seat:20
# None
# ...
# Ticket ID:2
# Seat Number:B
# Resvertation Status:reserved
# Price :50
# Event Name:Carnival of Colors
# Event date:1-January
# Venue:ABC Stadium
# Total Avaliable seat:20
# None
# *************
# Ticket ID:3
# Seat Number:C
# Resvertation Status:reserved
# Price :50
# Event Name:Carnival of Colors
# Event date:1-January
# Venue:ABC Stadium
# Total Avaliable seat:20
# None
# ----------------
# Ticket ID:4
# Seat Number:D
# Resvertation Status:Not reserved
# Price :50
# Event Name:Carnival of Colors
# Event date:1-January
# Venue:ABC Stadium
# Total Avaliable seat:20
# None
# --------------
# seats 19
# None
# ---------
